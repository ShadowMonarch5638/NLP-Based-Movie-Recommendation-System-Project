# %%
import pandas as pd
import numpy as np
credits_df = pd.read_csv("credits.csv")
movies_df = pd.read_csv("movies.csv")
credits_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
print("Credits:",credits_df.shape)  # N.O of rows and columns of the data set
print("Movies Dataframe:",movies_df.shape)
# Out:
# Credits: (4803, 4)
# Movies Dataframe: (4803, 20)

# %%
# we are merging both movies and creadits
movies_df=movies_df.merge(credits_df,on ='title')
movies_df.shape
# Out:
# (4808, 23)

# %%
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4808 entries, 0 to 4807
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4808 non-null   int64
#  1   genres                4808 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4808 non-null   int64
#  4   keywords              4808 non-null   object
#  5   original_language     4808 non-null   object
#  6   original_title        4808 non-null   object
#  7   overview              4805 non-null   object
#  8   popularity            4808 non-null   float64
#  9   production_companies  4808 non-null   object
#  10  production_countries  4808 non-null   object
#  11  release_date          4807 non-null   object
#  12  revenue               4808 non-null   int64
#  13  runtime               4806 non-null   float64
#  14  spoken_languages      4808 non-null   object
# ...

# %%
movies_df =movies_df[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
movies_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4808 entries, 0 to 4807
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4808 non-null   int64
#  1   title     4808 non-null   object
#  2   overview  4805 non-null   object
#  3   genres    4808 non-null   object
#  4   keywords  4808 non-null   object
#  5   cast      4808 non-null   object
#  6   crew      4808 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 300.5+ KB

# %% [markdown]
# Data cleaning process

# %%
# Count the number of missing values in each column of the 'movies_df' DataFrame
movies_df.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
# Remove rows with missing values from the 'movies_df' DataFrame in-place
movies_df.dropna(inplace=True)

# %%
# if sum is 0 that means there is no empty values in DataFrame
movies_df.duplicated().sum()
# Out:
# 0

# %%
# Retrieve the 'genres' column value of the first row (index 0) in the 'movies_df' DataFrame
movies_df.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
movies_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %% [markdown]
# AST(Abstract Syntax Trees)
#
# The ast module in Python helps analyze and understand the structure of Python code. It's useful for tasks like checking code quality, finding errors, and making automated changes to code. It's like a tool that helps Python programs understand and work with other Python code.
#
#
# > Indented block

# %%
# Import the 'ast' (Abstract Syntax Trees) module for parsing and working with Python literals
import ast

# %%
def convert(obj):
    # Initialize an empty list to store the extracted names
    L = []
    # Iterate through the list of dictionaries in 'obj'
    for i in ast.literal_eval(obj):
        # Append the 'name' field of each dictionary to the list 'L'
        L.append(i['name'])

    return L

def convert3(obj):
  L=[]
  counter=0
  for i in ast.literal_eval(obj):
      if counter != 3:
            L.append(i['name'])
            counter +=1
      else:
          break
      return L
def fetch_director(obj):
    L = []
    for i in ast.literal_eval(obj):
        if i['job'] == 'Director':
            L.append(i['name'])
            break
    return L

# %%
movies_df['genres']= movies_df['genres'].apply(convert)
movies_df['keywords']=movies_df['keywords'].apply(convert)

movies_df['cast']= movies_df['cast'].apply(convert3)
movies = movies_df  # Replace with your data source

# Apply the fetch_director function to the 'crew' column
movies['crew'] = movies['crew'].apply(fetch_director)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['overview'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
# Apply a lambda function to split the 'overview' column values in the 'movies' DataFrame into lists of words.
movies['overview']=movies['overview'].apply(lambda x:x.split() )

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
# Apply lambda functions to remove spaces from elements within the 'genres', 'keywords', and 'crew' columns in the 'movies' DataFrame.
movies['genres']=movies['genres'].apply(lambda x:[i.replace(" ","")for i in x])
movies['keywords']=movies['keywords'].apply(lambda x:[i.replace(" ","")for i in x])
movies['crew']=movies['crew'].apply(lambda x:[i.replace(" ","")for i in x])

# %%
movies['tags']=movies['overview']+movies['genres']+movies['keywords']+movies['cast']+movies['crew']
new_df=movies[['movie_id','title','tags']]

# %%
new_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...

# %%
# Apply a lambda function to concatenate elements in the 'tags' column of the 'new_df' DataFrame
# into a single string with space as the delimiter, if the column contains a list, otherwise keep the value as is.
new_df['tags'] = new_df['tags'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
new_df['tags'] = new_df['tags'].apply(lambda x: x.lower() if isinstance(x, str) else x)
# Out:
# <ipython-input-25-916c764c151c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
# <ipython-input-25-916c764c151c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x: x.lower() if isinstance(x, str) else x)

# %%
new_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  in the 22nd century, a paraplegic marine is di...
# 1  captain barbossa, long believed to be dead, ha...
# 2  a cryptic message from bond’s past sends him o...
# 3  following the death of district attorney harve...
# 4  john carter is a war-weary, former military ca...

# %% [markdown]
# COUNTVECTORIZER:
#
# .CountVectorizer is converts collection of the text document to matrix
#  of token count this produce the sparse representation
#
# .CountVectorizer is capture how often the word is occured in the document it count frequency of word and it show in matrix formats

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=5000,stop_words='english')

# %%
# arranges the data into a matrix.
# Each row stands for a document each column for a word, and the values show the word counts in each document.
new_df['tags'].fillna('', inplace=True)

vectors=cv.fit_transform(new_df['tags']).toarray()
# Out:
# <ipython-input-28-d4944400c608>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'].fillna('', inplace=True)

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Get the feature names (terms) extracted by the CountVectorizer (cv) for the 'tags' column in the DTM.
feature_names = cv.get_feature_names_out()
print(len(feature_names))
# Out:
# 5000

# %%
# Import the Natural Language Toolkit (NLTK) library for natural language processing and text analysis.
import nltk

# %%
# Import the Porter Stemmer from the NLTK library and create an instance of it.
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %% [markdown]
# PORTERSTEMMER
#
#
# words = ["program", "programs", "programmer", "programming", "programmers"]
#
# program  :  program
#
# programs  :  program
#
# programmer  :  program
#
# programming  :  program
#
# programmers  :  program

# %%
def stem(text):
  y=[]
  for i in text.split():
      y.append(ps.stem(i))
  return " ".join(y)

# %%
new_df['tags']=new_df['tags'].apply(stem)
# Out:
# <ipython-input-34-402dd7cb6b10>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(stem)

# %% [markdown]
# COSINE SIMILARITY
#
# Cosine similarity is used because it's good at measuring the similarity between items, particularly in text data. It's scale-invariant, angle-based, efficient, and works well for recommendation systems, clustering, and classification tasks.

# %%
# Import the 'cosine_similarity' function from the 'sklearn.metrics.pairwise' module
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Calculate the cosine similarity between vectors in the 'vectors' matrix
cosine_similarity_matrix = cosine_similarity(vectors)

# %%
cosine_similarity(vectors).shape
# Out:
# (4805, 4805)

# %%
similarity=cosine_similarity(vectors)
similarity[0]
# Out:
# array([1.        , 0.08858079, 0.05812382, ..., 0.02372895, 0.07798129,
#        0.        ])

# %%
# Sort the similarity scores for the first vector (index 0) and return the indices of the top 5 most similar vectors.

# 1. Use the 'enumerate' function to associate each similarity score with its index.
# 2. Sort the enumerated similarity scores in descending order (highest similarity first).
# 3. Extract the indices (vector indices) of the top 5 similar vectors.

similar_indices = sorted(enumerate(similarity[0]), reverse=True, key=lambda x: x[1])[1:6]

# %%
def recommend(movie):
    movie_index = new_df[new_df['title'] == movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)), key=lambda x: x[1], reverse=True)[1:6]


    for i in movies_list:
        recommended_movie_title = new_df.iloc[i[0]]['title']  # Access the 'title' from the DataFrame
        print(recommended_movie_title)

# %%
recommend("Iron Man")
# Out:
# Iron Man 3
# Iron Man 2
# Avengers: Age of Ultron
# The Avengers
# Ant-Man

# %%
recommend("Gandhi")
# Out:
# Gandhi, My Father
# The Wind That Shakes the Barley
# A Passage to India
# Guiana 1838
# Chariots of Fire

# %%
recommend("Avengers: Age of Ultron")
# Out:
# Iron Man
# Iron Man 3
# The Avengers
# Iron Man 2
# Captain America: Civil War

# %% [markdown]
# # **PLEASE IGNORE THE WARNINGS AS THEY DO NOT AFFECT THE MODEL**

# %% [markdown]
# # **THANK YOU**

# %% [markdown]
# # **LINK FOR THE ORIGINAL .ipynb FILE:**
# https://colab.research.google.com/drive/14YGsEmerMk9u6Xi3LC533K-Woa5I2Phl?usp=sharing
